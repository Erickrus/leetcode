# %% [markdown]
# <a href="https://colab.research.google.com/github/Erickrus/leetcode/blob/master/One_Shot_Free_View_Neural_Talking_Head.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # One-Shot Free-View Neural Talking-Head
#
#
# ### paper
# https://openaccess.thecvf.com/content/CVPR2021/papers/Wang_One-Shot_Free-View_Neural_Talking-Head_Synthesis_for_Video_Conferencing_CVPR_2021_paper.pdf
#
# ![](https://nvlabs.github.io/face-vid2vid/web_gifs/teaser.gif)
#
# ### 3rd party repository
#
# https://github.com/zhanglonghao1992/One-Shot_Free-View_Neural_Talking_Head_Synthesis

# %%
# install packages
# !git clone https://github.com/zhanglonghao1992/One-Shot_Free-View_Neural_Talking_Head_Synthesis
# !apt install -q tree
# !pip install face_alignment

# %%
# download weight file
# to get the updated link, visit: https://www.mediafire.com/folder/fcvtkn21j57bb/TalkingHead_Update
# !gdown https://download940.mediafire.com/qxqhtijr2v4g/f0utmig51dal20b/00000189-checkpoint.pth.tar
# !gdown https://download1655.mediafire.com/z6d38vpfql9g/lpxqkxkktmnj129/vox-256-spade.yaml

# %%
# render videos
# %cd /content/One-Shot_Free-View_Neural_Talking_Head_Synthesis
# !python demo.py --config /content/One-Shot_Free-View_Neural_Talking_Head_Synthesis/config/vox-256.yaml --checkpoint /content/00000189-checkpoint.pth.tar --source_image /content/002.png --driving_video /content/driving.mp4 --relative --adapt_scale --find_best_frame --result_video /content/result.mp4

# %%
# hstack driving and result video
# !ffmpeg -y -hide_banner -loglevel error -i /content/driving.mp4 -i /content/result.mp4 -filter_complex hstack /content/output.mp4

# display the video on colab page
from IPython.display import HTML
from base64 import b64encode
import os

videoFilename = "/content/output.mp4"
mp4 = open(videoFilename,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
